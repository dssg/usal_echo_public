# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

# %%
cd ../src
# Out:
# /home/ubuntu/yoni/usal_echo/src

# %%
from d05_measurement.calculate_meas import calculate_meas
calculation_df = calculate_meas('test_downsampleby5')
print(calculation_df.shape)
calculation_df
# Out:
# /home/ubuntu/anaconda3/envs/usal_echo/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# 100%|██████████| 103/103 [39:10<00:00, 18.32s/it]
# (2088, 7)
#      study_id  instance_id          file_name                   date_run  \
# 0       74958      1508983   a_74958_1GG0EP57 2019-08-16 14:42:36.873703
# 0       74958      1508983   a_74958_1GG0EP57 2019-08-16 14:42:36.873703
# 0       74958      1508983   a_74958_1GG0EP57 2019-08-16 14:42:36.873703
# 0       74958      1508983   a_74958_1GG0EP57 2019-08-16 14:42:36.873703
# 1       96624      2148595   a_96624_41PFB864 2019-08-16 14:42:36.873703
# ..        ...          ...                ...                        ...
# ...

# %%
print(calculation_df['measurement_value'].isnull().mean())
# Out:
# 0.5953065134099617

# %%
from d00_utils.db_utils import dbReadWriteMeasurement
io_measurement = dbReadWriteMeasurement()
io_measurement.save_to_db(calculation_df, 'calculations')

# %%
df = calculation_df[calculation_df['measurement_value'].notnull()]
print(df.shape)
df.head()
# Out:
# (845, 7)
#    study_id  instance_id         file_name                   date_run  \
# 0     74958      1508983  a_74958_1GG0EP57 2019-08-16 14:42:36.873703
# 0     74958      1508983  a_74958_1GG0EP57 2019-08-16 14:42:36.873703
# 0     74958      1508983  a_74958_1GG0EP57 2019-08-16 14:42:36.873703
# 0     74958      1508983  a_74958_1GG0EP57 2019-08-16 14:42:36.873703
# 6     89909      1963141  a_89909_E5JHWH6K 2019-08-16 14:42:36.873703
#
#   measurement_name measurement_unit measurement_value
# 0     VTD(MDD-ps4)               mL           105.618
# 0     VTS(MDD-ps4)               mL           69.6553
# 0      FE(MDD-ps4)                %           49.8492
# 0   recommendation                           greyzone
# 6     VTD(MDD-ps4)               mL           90.7861

# %%
pd.to_numeric(df[df['measurement_name']=='FE(MDD-ps4)']['measurement_value']).describe()
# Out:
# count    206.000000
# mean      51.798853
# std       15.217573
# min       11.468435
# 25%       42.635940
# 50%       52.494226
# 75%       63.310192
# max       79.736212
# Name: measurement_value, dtype: float64

# %%
df[df['measurement_name']=='recommendation']['measurement_value'].value_counts()
# Out:
# greyzone    102
# normal       61
# abnormal     43
# Name: measurement_value, dtype: int64
