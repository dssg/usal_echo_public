# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

# %%
from d05_measurement.analyse_segments import calculate_meas
df = calculate_meas('test_downsampleby5')
print(df.shape)
df
# Out:
# /home/ubuntu/anaconda3/envs/usal_echo/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
#   0%|          | 0/103 [00:00<?, ?it/s]
# (20, 7)
#    study_id  instance_id          file_name                   date_run  \
# 0     74958      1508983   a_74958_1GG0EP57 2019-08-15 20:20:28.215647
# 0     74958      1508983   a_74958_1GG0EP57 2019-08-15 20:20:28.215647
# 0     74958      1508983   a_74958_1GG0EP57 2019-08-15 20:20:28.215647
# 0     74958      1508983   a_74958_1GG0EP57 2019-08-15 20:20:28.215647
# 1     96624      2148595   a_96624_41PFB864 2019-08-15 20:20:28.215647
# 1     96624      2148595   a_96624_41PFB864 2019-08-15 20:20:28.215647
# 1     96624      2148595   a_96624_41PFB864 2019-08-15 20:20:28.215647
# 1     96624      2148595   a_96624_41PFB864 2019-08-15 20:20:28.215647
# 2     97220      2165100   a_97220_46RCF9AI 2019-08-15 20:20:28.215647
# 2     97220      2165100   a_97220_46RCF9AI 2019-08-15 20:20:28.215647
# 2     97220      2165100   a_97220_46RCF9AI 2019-08-15 20:20:28.215647
# 2     97220      2165100   a_97220_46RCF9AI 2019-08-15 20:20:28.215647
# 3    126172      2987140  a_126172_EBZCZ8AT 2019-08-15 20:20:28.215647
# 3    126172      2987140  a_126172_EBZCZ8AT 2019-08-15 20:20:28.215647
# 3    126172      2987140  a_126172_EBZCZ8AT 2019-08-15 20:20:28.215647
# 3    126172      2987140  a_126172_EBZCZ8AT 2019-08-15 20:20:28.215647
# 4    126442      2994496  a_126442_EEQL4LRY 2019-08-15 20:20:28.215647
# 4    126442      2994496  a_126442_EEQL4LRY 2019-08-15 20:20:28.215647
# 4    126442      2994496  a_126442_EEQL4LRY 2019-08-15 20:20:28.215647
# 4    126442      2994496  a_126442_EEQL4LRY 2019-08-15 20:20:28.215647
#
#   measurement_name measurement_unit measurement_value
# 0     VTD(MDD-ps4)               mL           105.618
# 0     VTS(MDD-ps4)               mL           69.6553
# 0      FE(MDD-ps4)                %           49.8492
# 0   recommendation                           greyzone
# 1     VTD(MDD-ps4)               mL               NaN
# 1     VTS(MDD-ps4)               mL               NaN
# 1      FE(MDD-ps4)                %               NaN
# 1   recommendation                                NaN
# 2     VTD(MDD-ps4)               mL               NaN
# 2     VTS(MDD-ps4)               mL               NaN
# 2      FE(MDD-ps4)                %               NaN
# 2   recommendation                                NaN
# 3     VTD(MDD-ps4)               mL               NaN
# 3     VTS(MDD-ps4)               mL               NaN
# 3      FE(MDD-ps4)                %               NaN
# 3   recommendation                                NaN
# 4     VTD(MDD-ps4)               mL               NaN
# 4     VTS(MDD-ps4)               mL               NaN
# 4      FE(MDD-ps4)                %               NaN
# 4   recommendation                                NaN

# %%
# from d00_utils.db_utils import dbReadWriteMeasurement
# io_measurement = dbReadWriteMeasurement()
# evaluations_df = io_measurement.get_table('evaluations')
# print(evaluations_df.shape)
# evaluations_df.head()
