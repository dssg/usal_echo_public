# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

# %%
folder = 'test_downsampleby5'
prediction_source = 'measurement_ground_truths'

# %%
from d05_measurement.write_evaluations import write_evaluations
df = write_evaluations(folder, prediction_source)
df.head()
# Out:
# Confusion matrix, without normalization
# [[146   0   0]
#  [  0  72   0]
#  [  0   0  15]]
# Normalized confusion matrix
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
#                             Measurements  Number Median Value (IQR)  \
# 0  Left ventricular diastolic volume, mL     238        86 (66-116)
# 1   Left ventricular systolic volume, mL     233         30 (21-46)
# 2  Left ventricular ejection fraction, %     233         63 (55-70)
#
#   Median Absolute Deviation (% of Manual)
# 0                                   0 (0)
# 1                                   0 (0)
# 2                                   0 (0)
