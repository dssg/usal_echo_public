# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

# %%
folder = 'test_downsampleby5'

# %%
from d05_measurement.analyse_segments import calculate_measurements
df = calculate_measurements(folder)
print(df.shape)
df.head()
# Out:
# /home/ubuntu/anaconda3/envs/usal_echo/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# (18, 13)
# []
# [106.01080296093093, 104.04659970539346, 103.27344378415434]
# ef: 0.033887996132051984
# [90.78613560088569]
# []
# []
# [67.56315215756715, 68.78198501856727, 69.3059088346159]
# [70.4855297629678, 72.87115627893866]
# []
# lavol: 1.9156755629460787
# [104.93025624129191, 88.06453676318951, 104.55110994711882]
# []
# []
# ef: 0.9156870421437185
# [73.50789434582984]
# []
# []
# []
# []
# []
# []
# Seconds: 161.6765580177307
# Seconds/File: 4.041913950443268
# skips: 0
# (72, 7)
#    study_id  instance_id         file_name                   date_run  \
# ...

# %%
import numpy as np
import pandas as pd
df[df['measurement_value'].isnull()]
# Out:
#     study_id  instance_id          file_name                   date_run  \
# 0      74920      1507806   a_74920_1FZH4296 2019-08-15 12:57:25.436586
# 1      74920      1507806   a_74920_1FZH4296 2019-08-15 12:57:25.436586
# 2      74920      1507806   a_74920_1FZH4296 2019-08-15 12:57:25.436586
# 10     89909      1963141   a_89909_E5JHWH6K 2019-08-15 12:57:25.436586
# 12     96624      2148595   a_96624_41PFB864 2019-08-15 12:57:25.436586
# 13     96624      2148595   a_96624_41PFB864 2019-08-15 12:57:25.436586
# 14     96624      2148595   a_96624_41PFB864 2019-08-15 12:57:25.436586
# 16    103898      2355254  a_103898_ABQ7JVTK 2019-08-15 12:57:25.436586
# 17    103898      2355254  a_103898_ABQ7JVTK 2019-08-15 12:57:25.436586
# 18    103898      2355254  a_103898_ABQ7JVTK 2019-08-15 12:57:25.436586
# 28    114188      2645647  a_114188_41920UKZ 2019-08-15 12:57:25.436586
# 29    114188      2645647  a_114188_41920UKZ 2019-08-15 12:57:25.436586
# ...
